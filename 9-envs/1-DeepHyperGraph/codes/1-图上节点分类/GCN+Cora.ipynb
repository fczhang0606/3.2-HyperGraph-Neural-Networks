# %%
import torch
import torch.nn.functional as F
import torch.optim as optim

from dhg.data import Cora
from dhg import Graph
from dhg.models import GCN
from dhg.metrics import GraphVertexClassificationEvaluator as Evaluator
from dhg.random import set_seed

import time
from copy import deepcopy

# %%
def train(A, X, lbls, net, train_idx, optimizer, epoch):

    net.train()

    st = time.time()
    optimizer.zero_grad()
    outs = net(X, A)
    outs, lbls = outs[train_idx], lbls[train_idx]
    loss = F.cross_entropy(outs, lbls)
    loss.backward()
    optimizer.step()

    print(f"Epoch: {epoch}, Time: {time.time()-st:.5f}s, Loss: {loss.item():.5f}")

    return loss.item()

# %%
@torch.no_grad()
def infer(A, X, lbls, net, idx, test=False):

    net.eval()

    outs = net(X, A)
    outs, lbls = outs[idx], lbls[idx]

    if not test:
        res = evaluator.validate(lbls, outs)
    else:
        res = evaluator.test(lbls, outs)

    return res

# %%
if __name__ == "__main__":

    set_seed(2024)

    device = torch.device("cuda") if torch.cuda.is_available() else torch.device("cpu")

    ################################################################
    data = Cora()
    G = Graph(data["num_vertices"], data["edge_list"])
    X, lbl = data["features"], data["labels"]

    train_mask = data["train_mask"]
    val_mask   = data["val_mask"]
    test_mask  = data["test_mask"]

    net = GCN(data["dim_features"], 16, data["num_classes"])
    optimizer = optim.Adam(net.parameters(), lr=0.01, weight_decay=5e-4)

    evaluator = Evaluator(["accuracy", "f1_score", {"f1_score": {"average": "micro"}}])

    ################################################################
    G = G.to(device)
    X, lbl = X.to(device), lbl.to(device)
    net = net.to(device)

    ################################################################
    best_val = 0
    best_state = None
    best_epoch = 0
    for epoch in range(300):

        # train, 每轮optimizer的参数在优化
        train(G, X, lbl, net, train_mask, optimizer, epoch)

        # validation
        if epoch % 1 == 0:
            with torch.no_grad():
                val_res = infer(G, X, lbl, net, val_mask)
            if val_res > best_val:
                print(f"update best: {val_res:.5f}")
                best_val   = val_res
                best_state = deepcopy(net.state_dict())
                best_epoch = epoch

    print("\ntrain finished!")
    print(f"best val: {best_val:.5f}")

    # test
    print("test...")
    net.load_state_dict(best_state)
    res = infer(G, X, lbl, net, test_mask, test=True)
    print(f"final result: epoch: {best_epoch}")
    print(res)
# Out:
# Epoch: 0, Time: 0.33405s, Loss: 1.96712
# update best: 0.05800
# Epoch: 1, Time: 0.00088s, Loss: 1.96182
# Epoch: 2, Time: 0.00087s, Loss: 1.95624
# Epoch: 3, Time: 0.00079s, Loss: 1.95098
# Epoch: 4, Time: 0.00083s, Loss: 1.94301
# update best: 0.10800
# Epoch: 5, Time: 0.00079s, Loss: 1.93629
# update best: 0.15400
# Epoch: 6, Time: 0.00081s, Loss: 1.93044
# Epoch: 7, Time: 0.00077s, Loss: 1.92347
# Epoch: 8, Time: 0.00078s, Loss: 1.91221
# Epoch: 9, Time: 0.00068s, Loss: 1.90219
# Epoch: 10, Time: 0.00066s, Loss: 1.90319
# update best: 0.20000
# Epoch: 11, Time: 0.00069s, Loss: 1.88750
# update best: 0.27600
# Epoch: 12, Time: 0.00125s, Loss: 1.88159
# update best: 0.29400
# Epoch: 13, Time: 0.00077s, Loss: 1.87375
# Epoch: 14, Time: 0.00076s, Loss: 1.86158
# Epoch: 15, Time: 0.00084s, Loss: 1.85921
# Epoch: 16, Time: 0.00090s, Loss: 1.84759
# Epoch: 17, Time: 0.00089s, Loss: 1.83661
# Epoch: 18, Time: 0.00094s, Loss: 1.81793
# Epoch: 19, Time: 0.00090s, Loss: 1.81405
# Epoch: 20, Time: 0.00090s, Loss: 1.80205
# Epoch: 21, Time: 0.00091s, Loss: 1.78578
# Epoch: 22, Time: 0.00090s, Loss: 1.78013
# update best: 0.30600
# Epoch: 23, Time: 0.00091s, Loss: 1.76389
# update best: 0.32000
# Epoch: 24, Time: 0.00091s, Loss: 1.76050
# update best: 0.34000
# Epoch: 25, Time: 0.00092s, Loss: 1.73937
# update best: 0.35600
# Epoch: 26, Time: 0.00095s, Loss: 1.72949
# update best: 0.36600
# Epoch: 27, Time: 0.00092s, Loss: 1.70320
# update best: 0.37200
# Epoch: 28, Time: 0.00092s, Loss: 1.68516
# update best: 0.38200
# Epoch: 29, Time: 0.00079s, Loss: 1.68818
# update best: 0.39600
# Epoch: 30, Time: 0.00078s, Loss: 1.65412
# update best: 0.40800
# Epoch: 31, Time: 0.00078s, Loss: 1.65520
# update best: 0.42600
# Epoch: 32, Time: 0.00071s, Loss: 1.64146
# update best: 0.44200
# Epoch: 33, Time: 0.00069s, Loss: 1.63447
# update best: 0.46400
# Epoch: 34, Time: 0.00070s, Loss: 1.59413
# update best: 0.49200
# Epoch: 35, Time: 0.00069s, Loss: 1.57794
# update best: 0.52000
# Epoch: 36, Time: 0.00068s, Loss: 1.55214
# update best: 0.56200
# Epoch: 37, Time: 0.00070s, Loss: 1.54308
# update best: 0.59600
# Epoch: 38, Time: 0.00069s, Loss: 1.52492
# update best: 0.62200
# Epoch: 39, Time: 0.00068s, Loss: 1.49988
# update best: 0.65400
# Epoch: 40, Time: 0.00119s, Loss: 1.48514
# update best: 0.68000
# Epoch: 41, Time: 0.00069s, Loss: 1.47559
# update best: 0.70000
# Epoch: 42, Time: 0.00089s, Loss: 1.46056
# update best: 0.70600
# Epoch: 43, Time: 0.00082s, Loss: 1.41901
# Epoch: 44, Time: 0.00081s, Loss: 1.40697
# update best: 0.71400
# Epoch: 45, Time: 0.00084s, Loss: 1.39727
# Epoch: 46, Time: 0.00087s, Loss: 1.37485
# update best: 0.71600
# Epoch: 47, Time: 0.00091s, Loss: 1.36356
# update best: 0.71800
# Epoch: 48, Time: 0.00091s, Loss: 1.34874
# update best: 0.72000
# Epoch: 49, Time: 0.00088s, Loss: 1.29339
# update best: 0.73000
# Epoch: 50, Time: 0.00088s, Loss: 1.31889
# update best: 0.74400
# Epoch: 51, Time: 0.00084s, Loss: 1.25756
# Epoch: 52, Time: 0.00085s, Loss: 1.23726
# update best: 0.75800
# Epoch: 53, Time: 0.00085s, Loss: 1.23599
# Epoch: 54, Time: 0.00080s, Loss: 1.22539
# Epoch: 55, Time: 0.00084s, Loss: 1.17902
# Epoch: 56, Time: 0.00072s, Loss: 1.19396
# update best: 0.76200
# Epoch: 57, Time: 0.00070s, Loss: 1.16762
# update best: 0.76400
# Epoch: 58, Time: 0.00071s, Loss: 1.14398
# Epoch: 59, Time: 0.00067s, Loss: 1.11566
# Epoch: 60, Time: 0.00066s, Loss: 1.12557
# Epoch: 61, Time: 0.00067s, Loss: 1.09361
# Epoch: 62, Time: 0.00066s, Loss: 1.07387
# update best: 0.76800
# Epoch: 63, Time: 0.00073s, Loss: 1.03507
# update best: 0.77000
# Epoch: 64, Time: 0.00069s, Loss: 1.04819
# Epoch: 65, Time: 0.00066s, Loss: 1.01536
# Epoch: 66, Time: 0.00066s, Loss: 1.02086
# update best: 0.77600
# Epoch: 67, Time: 0.00069s, Loss: 1.00379
# update best: 0.77800
# Epoch: 68, Time: 0.00068s, Loss: 0.99359
# update best: 0.78800
# Epoch: 69, Time: 0.00069s, Loss: 0.94938
# update best: 0.79200
# Epoch: 70, Time: 0.00130s, Loss: 0.94559
# Epoch: 71, Time: 0.00072s, Loss: 0.91210
# Epoch: 72, Time: 0.00067s, Loss: 0.93543
# Epoch: 73, Time: 0.00066s, Loss: 0.91468
# Epoch: 74, Time: 0.00066s, Loss: 0.87600
# Epoch: 75, Time: 0.00066s, Loss: 0.87029
# Epoch: 76, Time: 0.00070s, Loss: 0.85010
# Epoch: 77, Time: 0.00066s, Loss: 0.86409
# Epoch: 78, Time: 0.00066s, Loss: 0.82224
# Epoch: 79, Time: 0.00065s, Loss: 0.87215
# Epoch: 80, Time: 0.00066s, Loss: 0.86201
# Epoch: 81, Time: 0.00065s, Loss: 0.80581
# Epoch: 82, Time: 0.00065s, Loss: 0.83197
# Epoch: 83, Time: 0.00065s, Loss: 0.78902
# Epoch: 84, Time: 0.00066s, Loss: 0.75661
# Epoch: 85, Time: 0.00065s, Loss: 0.72292
# Epoch: 86, Time: 0.00065s, Loss: 0.75302
# Epoch: 87, Time: 0.00065s, Loss: 0.72047
# Epoch: 88, Time: 0.00126s, Loss: 0.68792
# update best: 0.79600
# Epoch: 89, Time: 0.00070s, Loss: 0.70285
# Epoch: 90, Time: 0.00066s, Loss: 0.69462
# Epoch: 91, Time: 0.00066s, Loss: 0.67117
# Epoch: 92, Time: 0.00067s, Loss: 0.68672
# Epoch: 93, Time: 0.00065s, Loss: 0.67587
# Epoch: 94, Time: 0.00065s, Loss: 0.69313
# Epoch: 95, Time: 0.00065s, Loss: 0.67078
# Epoch: 96, Time: 0.00065s, Loss: 0.65881
# Epoch: 97, Time: 0.00066s, Loss: 0.63990
# Epoch: 98, Time: 0.00066s, Loss: 0.65155
# Epoch: 99, Time: 0.00065s, Loss: 0.63963
# Epoch: 100, Time: 0.00066s, Loss: 0.61616
# Epoch: 101, Time: 0.00066s, Loss: 0.64636
# Epoch: 102, Time: 0.00066s, Loss: 0.59681
# Epoch: 103, Time: 0.00066s, Loss: 0.62500
# Epoch: 104, Time: 0.00065s, Loss: 0.62181
# Epoch: 105, Time: 0.00064s, Loss: 0.56579
# Epoch: 106, Time: 0.00128s, Loss: 0.63944
# Epoch: 107, Time: 0.00065s, Loss: 0.62056
# Epoch: 108, Time: 0.00066s, Loss: 0.62649
# Epoch: 109, Time: 0.00065s, Loss: 0.58805
# Epoch: 110, Time: 0.00067s, Loss: 0.59497
# Epoch: 111, Time: 0.00065s, Loss: 0.59555
# Epoch: 112, Time: 0.00065s, Loss: 0.56562
# Epoch: 113, Time: 0.00065s, Loss: 0.56159
# Epoch: 114, Time: 0.00065s, Loss: 0.49584
# Epoch: 115, Time: 0.00067s, Loss: 0.55615
# Epoch: 116, Time: 0.00066s, Loss: 0.52641
# Epoch: 117, Time: 0.00066s, Loss: 0.51471
# Epoch: 118, Time: 0.00065s, Loss: 0.53668
# Epoch: 119, Time: 0.00066s, Loss: 0.53030
# Epoch: 120, Time: 0.00065s, Loss: 0.56527
# Epoch: 121, Time: 0.00065s, Loss: 0.55124
# Epoch: 122, Time: 0.00066s, Loss: 0.48663
# Epoch: 123, Time: 0.00066s, Loss: 0.50301
# Epoch: 124, Time: 0.00065s, Loss: 0.50007
# Epoch: 125, Time: 0.00065s, Loss: 0.49128
# Epoch: 126, Time: 0.00065s, Loss: 0.52148
# Epoch: 127, Time: 0.00064s, Loss: 0.50549
# Epoch: 128, Time: 0.00066s, Loss: 0.50728
# Epoch: 129, Time: 0.00065s, Loss: 0.50563
# Epoch: 130, Time: 0.00065s, Loss: 0.49445
# Epoch: 131, Time: 0.00066s, Loss: 0.50208
# Epoch: 132, Time: 0.00065s, Loss: 0.49384
# Epoch: 133, Time: 0.00065s, Loss: 0.49740
# Epoch: 134, Time: 0.00065s, Loss: 0.49494
# Epoch: 135, Time: 0.00065s, Loss: 0.45260
# update best: 0.79800
# Epoch: 136, Time: 0.00068s, Loss: 0.46089
# Epoch: 137, Time: 0.00067s, Loss: 0.47734
# Epoch: 138, Time: 0.00065s, Loss: 0.42326
# Epoch: 139, Time: 0.00065s, Loss: 0.50842
# Epoch: 140, Time: 0.00065s, Loss: 0.44007
# Epoch: 141, Time: 0.00065s, Loss: 0.43274
# Epoch: 142, Time: 0.00065s, Loss: 0.44679
# Epoch: 143, Time: 0.00087s, Loss: 0.45524
# Epoch: 144, Time: 0.00065s, Loss: 0.44573
# Epoch: 145, Time: 0.00065s, Loss: 0.45184
# Epoch: 146, Time: 0.00066s, Loss: 0.44675
# Epoch: 147, Time: 0.00067s, Loss: 0.42508
# Epoch: 148, Time: 0.00065s, Loss: 0.43928
# Epoch: 149, Time: 0.00065s, Loss: 0.43553
# Epoch: 150, Time: 0.00066s, Loss: 0.45770
# Epoch: 151, Time: 0.00065s, Loss: 0.42385
# Epoch: 152, Time: 0.00065s, Loss: 0.39966
# Epoch: 153, Time: 0.00065s, Loss: 0.40300
# Epoch: 154, Time: 0.00068s, Loss: 0.37415
# Epoch: 155, Time: 0.00066s, Loss: 0.38938
# Epoch: 156, Time: 0.00065s, Loss: 0.40925
# Epoch: 157, Time: 0.00065s, Loss: 0.41975
# Epoch: 158, Time: 0.00066s, Loss: 0.41070
# Epoch: 159, Time: 0.00065s, Loss: 0.46415
# Epoch: 160, Time: 0.00065s, Loss: 0.39674
# Epoch: 161, Time: 0.00128s, Loss: 0.40262
# Epoch: 162, Time: 0.00065s, Loss: 0.40883
# Epoch: 163, Time: 0.00066s, Loss: 0.40084
# Epoch: 164, Time: 0.00065s, Loss: 0.40199
# Epoch: 165, Time: 0.00065s, Loss: 0.43319
# Epoch: 166, Time: 0.00065s, Loss: 0.40004
# Epoch: 167, Time: 0.00066s, Loss: 0.41217
# Epoch: 168, Time: 0.00065s, Loss: 0.37678
# Epoch: 169, Time: 0.00065s, Loss: 0.42410
# Epoch: 170, Time: 0.00066s, Loss: 0.38999
# Epoch: 171, Time: 0.00065s, Loss: 0.36569
# Epoch: 172, Time: 0.00066s, Loss: 0.37809
# Epoch: 173, Time: 0.00065s, Loss: 0.37626
# Epoch: 174, Time: 0.00064s, Loss: 0.38266
# Epoch: 175, Time: 0.00066s, Loss: 0.37995
# Epoch: 176, Time: 0.00066s, Loss: 0.37397
# Epoch: 177, Time: 0.00065s, Loss: 0.32809
# Epoch: 178, Time: 0.00065s, Loss: 0.38184
# Epoch: 179, Time: 0.00065s, Loss: 0.40044
# Epoch: 180, Time: 0.00066s, Loss: 0.37905
# Epoch: 181, Time: 0.00065s, Loss: 0.36558
# Epoch: 182, Time: 0.00066s, Loss: 0.35638
# Epoch: 183, Time: 0.00065s, Loss: 0.37823
# Epoch: 184, Time: 0.00065s, Loss: 0.35706
# Epoch: 185, Time: 0.00066s, Loss: 0.34423
# Epoch: 186, Time: 0.00066s, Loss: 0.38345
# Epoch: 187, Time: 0.00065s, Loss: 0.37227
# Epoch: 188, Time: 0.00066s, Loss: 0.36044
# Epoch: 189, Time: 0.00065s, Loss: 0.36309
# Epoch: 190, Time: 0.00066s, Loss: 0.39603
# Epoch: 191, Time: 0.00066s, Loss: 0.34521
# Epoch: 192, Time: 0.00066s, Loss: 0.37799
# Epoch: 193, Time: 0.00065s, Loss: 0.36441
# Epoch: 194, Time: 0.00067s, Loss: 0.33485
# Epoch: 195, Time: 0.00065s, Loss: 0.36475
# Epoch: 196, Time: 0.00066s, Loss: 0.36368
# Epoch: 197, Time: 0.00065s, Loss: 0.31534
# Epoch: 198, Time: 0.00127s, Loss: 0.38543
# Epoch: 199, Time: 0.00065s, Loss: 0.36031
# Epoch: 200, Time: 0.00064s, Loss: 0.33713
# Epoch: 201, Time: 0.00065s, Loss: 0.34579
# Epoch: 202, Time: 0.00083s, Loss: 0.35176
# Epoch: 203, Time: 0.00070s, Loss: 0.35112
# Epoch: 204, Time: 0.00067s, Loss: 0.31315
# Epoch: 205, Time: 0.00067s, Loss: 0.34622
# Epoch: 206, Time: 0.00069s, Loss: 0.31725
# Epoch: 207, Time: 0.00068s, Loss: 0.36459
# Epoch: 208, Time: 0.00068s, Loss: 0.31932
# Epoch: 209, Time: 0.00067s, Loss: 0.31594
# Epoch: 210, Time: 0.00070s, Loss: 0.34911
# Epoch: 211, Time: 0.00131s, Loss: 0.31459
# Epoch: 212, Time: 0.00067s, Loss: 0.32776
# Epoch: 213, Time: 0.00070s, Loss: 0.32461
# Epoch: 214, Time: 0.00066s, Loss: 0.31336
# Epoch: 215, Time: 0.00069s, Loss: 0.29177
# Epoch: 216, Time: 0.00066s, Loss: 0.31155
# Epoch: 217, Time: 0.00065s, Loss: 0.33271
# Epoch: 218, Time: 0.00065s, Loss: 0.29347
# Epoch: 219, Time: 0.00066s, Loss: 0.33732
# Epoch: 220, Time: 0.00066s, Loss: 0.30876
# Epoch: 221, Time: 0.00067s, Loss: 0.31738
# Epoch: 222, Time: 0.00066s, Loss: 0.32593
# Epoch: 223, Time: 0.00066s, Loss: 0.34876
# Epoch: 224, Time: 0.00066s, Loss: 0.34451
# Epoch: 225, Time: 0.00066s, Loss: 0.31874
# Epoch: 226, Time: 0.00066s, Loss: 0.32399
# Epoch: 227, Time: 0.00066s, Loss: 0.33375
# Epoch: 228, Time: 0.00066s, Loss: 0.31065
# Epoch: 229, Time: 0.00066s, Loss: 0.34256
# Epoch: 230, Time: 0.00065s, Loss: 0.32412
# Epoch: 231, Time: 0.00066s, Loss: 0.30349
# Epoch: 232, Time: 0.00141s, Loss: 0.32238
# Epoch: 233, Time: 0.00065s, Loss: 0.30401
# Epoch: 234, Time: 0.00066s, Loss: 0.32943
# Epoch: 235, Time: 0.00067s, Loss: 0.32576
# Epoch: 236, Time: 0.00066s, Loss: 0.31853
# Epoch: 237, Time: 0.00065s, Loss: 0.30126
# Epoch: 238, Time: 0.00066s, Loss: 0.33401
# Epoch: 239, Time: 0.00066s, Loss: 0.31395
# Epoch: 240, Time: 0.00066s, Loss: 0.30885
# Epoch: 241, Time: 0.00066s, Loss: 0.27750
# Epoch: 242, Time: 0.00066s, Loss: 0.35376
# Epoch: 243, Time: 0.00065s, Loss: 0.26178
# Epoch: 244, Time: 0.00065s, Loss: 0.30539
# Epoch: 245, Time: 0.00066s, Loss: 0.29093
# Epoch: 246, Time: 0.00065s, Loss: 0.29393
# Epoch: 247, Time: 0.00065s, Loss: 0.25817
# Epoch: 248, Time: 0.00065s, Loss: 0.28662
# Epoch: 249, Time: 0.00065s, Loss: 0.29644
# Epoch: 250, Time: 0.00088s, Loss: 0.29207
# Epoch: 251, Time: 0.00065s, Loss: 0.32466
# update best: 0.80000
# Epoch: 252, Time: 0.00070s, Loss: 0.28845
# Epoch: 253, Time: 0.00067s, Loss: 0.30925
# Epoch: 254, Time: 0.00066s, Loss: 0.27319
# Epoch: 255, Time: 0.00066s, Loss: 0.25655
# Epoch: 256, Time: 0.00065s, Loss: 0.31010
# Epoch: 257, Time: 0.00067s, Loss: 0.31601
# Epoch: 258, Time: 0.00065s, Loss: 0.33674
# Epoch: 259, Time: 0.00066s, Loss: 0.27615
# Epoch: 260, Time: 0.00065s, Loss: 0.32289
# Epoch: 261, Time: 0.00066s, Loss: 0.27248
# Epoch: 262, Time: 0.00067s, Loss: 0.25458
# Epoch: 263, Time: 0.00065s, Loss: 0.27373
# Epoch: 264, Time: 0.00065s, Loss: 0.33899
# Epoch: 265, Time: 0.00068s, Loss: 0.31276
# Epoch: 266, Time: 0.00067s, Loss: 0.27532
# Epoch: 267, Time: 0.00065s, Loss: 0.30080
# Epoch: 268, Time: 0.00151s, Loss: 0.26987
# Epoch: 269, Time: 0.00082s, Loss: 0.22755
# Epoch: 270, Time: 0.00081s, Loss: 0.29357
# Epoch: 271, Time: 0.00082s, Loss: 0.30591
# Epoch: 272, Time: 0.00080s, Loss: 0.25503
# Epoch: 273, Time: 0.00082s, Loss: 0.28478
# Epoch: 274, Time: 0.00081s, Loss: 0.27574
# Epoch: 275, Time: 0.00081s, Loss: 0.27607
# Epoch: 276, Time: 0.00081s, Loss: 0.32425
# Epoch: 277, Time: 0.00081s, Loss: 0.27747
# Epoch: 278, Time: 0.00081s, Loss: 0.28520
# Epoch: 279, Time: 0.00080s, Loss: 0.28399
# Epoch: 280, Time: 0.00080s, Loss: 0.31290
# Epoch: 281, Time: 0.00080s, Loss: 0.30268
# Epoch: 282, Time: 0.00079s, Loss: 0.24499
# Epoch: 283, Time: 0.00078s, Loss: 0.27599
# Epoch: 284, Time: 0.00139s, Loss: 0.30495
# Epoch: 285, Time: 0.00078s, Loss: 0.28884
# Epoch: 286, Time: 0.00078s, Loss: 0.27958
# Epoch: 287, Time: 0.00078s, Loss: 0.25977
# Epoch: 288, Time: 0.00078s, Loss: 0.32232
# Epoch: 289, Time: 0.00081s, Loss: 0.27338
# Epoch: 290, Time: 0.00066s, Loss: 0.26273
# Epoch: 291, Time: 0.00066s, Loss: 0.25678
# Epoch: 292, Time: 0.00066s, Loss: 0.27225
# Epoch: 293, Time: 0.00066s, Loss: 0.27794
# Epoch: 294, Time: 0.00065s, Loss: 0.27565
# Epoch: 295, Time: 0.00064s, Loss: 0.29664
# Epoch: 296, Time: 0.00065s, Loss: 0.26629
# Epoch: 297, Time: 0.00065s, Loss: 0.29623
# Epoch: 298, Time: 0.00064s, Loss: 0.27485
# Epoch: 299, Time: 0.00065s, Loss: 0.27884
#
# train finished!
# best val: 0.80000
# test...
# final result: epoch: 251
# {'accuracy': 0.8159999847412109, 'f1_score': 0.8050299436379041, 'f1_score -> average@micro': 0.816}
