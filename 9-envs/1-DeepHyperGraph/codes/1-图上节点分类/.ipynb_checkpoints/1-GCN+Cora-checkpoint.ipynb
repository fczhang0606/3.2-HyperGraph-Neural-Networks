# %%
import torch
import torch.nn.functional as F
import torch.optim as optim

from dhg.data import Cora
from dhg import Graph
from dhg.models import GCN
from dhg.metrics import GraphVertexClassificationEvaluator as Evaluator
from dhg.random import set_seed

import time
from copy import deepcopy

# %%
def train(A, X, lbls, net, train_idx, optimizer, epoch):

    net.train()

    st = time.time()
    optimizer.zero_grad()
    outs = net(X, A)
    outs, lbls = outs[train_idx], lbls[train_idx]
    loss = F.cross_entropy(outs, lbls)
    loss.backward()
    optimizer.step()

    print(f"Epoch: {epoch}, Time: {time.time()-st:.5f}s, Loss: {loss.item():.5f}")

    return loss.item()

# %%
@torch.no_grad()
def infer(A, X, lbls, net, idx, test=False):

    net.eval()

    outs = net(X, A)
    outs, lbls = outs[idx], lbls[idx]

    if not test:
        res = evaluator.validate(lbls, outs)
    else:
        res = evaluator.test(lbls, outs)

    return res

# %%
if __name__ == "__main__":

    set_seed(2022)

    device = torch.device("cuda") if torch.cuda.is_available() else torch.device("cpu")

    ################################################################
    data = Cora()
    G = Graph(data["num_vertices"], data["edge_list"])
    X, lbl = data["features"], data["labels"]

    train_mask = data["train_mask"]
    val_mask   = data["val_mask"]
    test_mask  = data["test_mask"]

    net = GCN(data["dim_features"], 16, data["num_classes"])
    optimizer = optim.Adam(net.parameters(), lr=0.01, weight_decay=5e-4)

    evaluator = Evaluator(["accuracy", "f1_score", {"f1_score": {"average": "micro"}}])

    ################################################################
    G = G.to(device)
    X, lbl = X.to(device), lbl.to(device)
    net = net.to(device)

    ################################################################
    best_val = 0
    best_state = None
    best_epoch = 0
    for epoch in range(300):

        # train, 每轮optimizer的参数在优化
        train(G, X, lbl, net, train_mask, optimizer, epoch)

        # validation
        if epoch % 1 == 0:
            with torch.no_grad():
                val_res = infer(G, X, lbl, net, val_mask)
            if val_res > best_val:
                print(f"update best: {val_res:.5f}")
                best_val   = val_res
                best_state = deepcopy(net.state_dict())
                best_epoch = epoch

    print("\ntrain finished!")
    print(f"best val: {best_val:.5f}")

    # test
    print("test...")
    net.load_state_dict(best_state)
    res = infer(G, X, lbl, net, test_mask, test=True)
    print(f"final result: epoch: {best_epoch}")
    print(res)
# Out:
# Epoch: 0, Time: 0.32276s, Loss: 1.95010
# update best: 0.31600
# Epoch: 1, Time: 0.00105s, Loss: 1.94601
# Epoch: 2, Time: 0.00096s, Loss: 1.94383
# Epoch: 3, Time: 0.00102s, Loss: 1.93907
# Epoch: 4, Time: 0.00104s, Loss: 1.93350
# update best: 0.38000
# Epoch: 5, Time: 0.00095s, Loss: 1.92899
# Epoch: 6, Time: 0.00096s, Loss: 1.92461
# Epoch: 7, Time: 0.00098s, Loss: 1.91764
# Epoch: 8, Time: 0.00093s, Loss: 1.91163
# Epoch: 9, Time: 0.00094s, Loss: 1.90064
# Epoch: 10, Time: 0.00166s, Loss: 1.89617
# Epoch: 11, Time: 0.00087s, Loss: 1.88721
# Epoch: 12, Time: 0.00082s, Loss: 1.87626
# Epoch: 13, Time: 0.00085s, Loss: 1.86941
# Epoch: 14, Time: 0.00087s, Loss: 1.86202
# Epoch: 15, Time: 0.00082s, Loss: 1.85207
# Epoch: 16, Time: 0.00084s, Loss: 1.84285
# Epoch: 17, Time: 0.00085s, Loss: 1.83392
# Epoch: 18, Time: 0.00081s, Loss: 1.82120
# Epoch: 19, Time: 0.00080s, Loss: 1.80663
# Epoch: 20, Time: 0.00072s, Loss: 1.79340
# Epoch: 21, Time: 0.00077s, Loss: 1.77829
# Epoch: 22, Time: 0.00070s, Loss: 1.76851
# update best: 0.38800
# Epoch: 23, Time: 0.00074s, Loss: 1.75592
# update best: 0.40200
# Epoch: 24, Time: 0.00072s, Loss: 1.74545
# update best: 0.43000
# Epoch: 25, Time: 0.00144s, Loss: 1.72373
# update best: 0.45000
# Epoch: 26, Time: 0.00071s, Loss: 1.71025
# update best: 0.46000
# Epoch: 27, Time: 0.00074s, Loss: 1.68904
# update best: 0.46400
# Epoch: 28, Time: 0.00071s, Loss: 1.67401
# update best: 0.46600
# Epoch: 29, Time: 0.00073s, Loss: 1.67025
# update best: 0.48400
# Epoch: 30, Time: 0.00071s, Loss: 1.65349
# update best: 0.49200
# Epoch: 31, Time: 0.00082s, Loss: 1.61911
# update best: 0.49800
# Epoch: 32, Time: 0.00080s, Loss: 1.61325
# update best: 0.51400
# Epoch: 33, Time: 0.00079s, Loss: 1.56832
# update best: 0.52600
# Epoch: 34, Time: 0.00082s, Loss: 1.55827
# update best: 0.55000
# Epoch: 35, Time: 0.00077s, Loss: 1.55186
# update best: 0.56200
# Epoch: 36, Time: 0.00073s, Loss: 1.53794
# update best: 0.57400
# Epoch: 37, Time: 0.00073s, Loss: 1.50345
# update best: 0.58600
# Epoch: 38, Time: 0.00082s, Loss: 1.49760
# update best: 0.59600
# Epoch: 39, Time: 0.00155s, Loss: 1.47143
# update best: 0.60200
# Epoch: 40, Time: 0.00079s, Loss: 1.43501
# update best: 0.62800
# Epoch: 41, Time: 0.00074s, Loss: 1.42085
# update best: 0.64800
# Epoch: 42, Time: 0.00074s, Loss: 1.38769
# update best: 0.65400
# Epoch: 43, Time: 0.00070s, Loss: 1.36689
# update best: 0.66200
# Epoch: 44, Time: 0.00074s, Loss: 1.36428
# update best: 0.66800
# Epoch: 45, Time: 0.00082s, Loss: 1.32395
# Epoch: 46, Time: 0.00071s, Loss: 1.29274
# update best: 0.67600
# Epoch: 47, Time: 0.00071s, Loss: 1.30380
# Epoch: 48, Time: 0.00074s, Loss: 1.26099
# update best: 0.68800
# Epoch: 49, Time: 0.00071s, Loss: 1.25379
# Epoch: 50, Time: 0.00075s, Loss: 1.23854
# update best: 0.69800
# Epoch: 51, Time: 0.00072s, Loss: 1.20378
# update best: 0.72200
# Epoch: 52, Time: 0.00082s, Loss: 1.16979
# update best: 0.73200
# Epoch: 53, Time: 0.00074s, Loss: 1.15275
# update best: 0.74800
# Epoch: 54, Time: 0.00074s, Loss: 1.11128
# update best: 0.75200
# Epoch: 55, Time: 0.00075s, Loss: 1.12654
# update best: 0.75600
# Epoch: 56, Time: 0.00069s, Loss: 1.12641
# update best: 0.76400
# Epoch: 57, Time: 0.00077s, Loss: 1.08093
# update best: 0.76600
# Epoch: 58, Time: 0.00075s, Loss: 1.06145
# Epoch: 59, Time: 0.00070s, Loss: 1.03330
# Epoch: 60, Time: 0.00068s, Loss: 1.02479
# Epoch: 61, Time: 0.00068s, Loss: 1.01496
# Epoch: 62, Time: 0.00068s, Loss: 0.93007
# Epoch: 63, Time: 0.00070s, Loss: 0.97366
# Epoch: 64, Time: 0.00069s, Loss: 0.92534
# Epoch: 65, Time: 0.00069s, Loss: 0.91500
# update best: 0.77400
# Epoch: 66, Time: 0.00072s, Loss: 0.93400
# update best: 0.77800
# Epoch: 67, Time: 0.00072s, Loss: 0.86869
# update best: 0.78000
# Epoch: 68, Time: 0.00071s, Loss: 0.89109
# Epoch: 69, Time: 0.00068s, Loss: 0.89371
# Epoch: 70, Time: 0.00071s, Loss: 0.87362
# update best: 0.78200
# Epoch: 71, Time: 0.00072s, Loss: 0.80287
# Epoch: 72, Time: 0.00071s, Loss: 0.88049
# Epoch: 73, Time: 0.00072s, Loss: 0.78692
# Epoch: 74, Time: 0.00068s, Loss: 0.79204
# Epoch: 75, Time: 0.00070s, Loss: 0.81149
# update best: 0.78400
# Epoch: 76, Time: 0.00071s, Loss: 0.79278
# Epoch: 77, Time: 0.00068s, Loss: 0.75974
# update best: 0.78600
# Epoch: 78, Time: 0.00072s, Loss: 0.74237
# Epoch: 79, Time: 0.00071s, Loss: 0.72129
# update best: 0.78800
# Epoch: 80, Time: 0.00071s, Loss: 0.72252
# update best: 0.79000
# Epoch: 81, Time: 0.00074s, Loss: 0.69306
# update best: 0.79200
# Epoch: 82, Time: 0.00071s, Loss: 0.64976
# Epoch: 83, Time: 0.00070s, Loss: 0.66782
# Epoch: 84, Time: 0.00070s, Loss: 0.68008
# Epoch: 85, Time: 0.00068s, Loss: 0.70714
# Epoch: 86, Time: 0.00137s, Loss: 0.64139
# Epoch: 87, Time: 0.00069s, Loss: 0.66335
# Epoch: 88, Time: 0.00069s, Loss: 0.65881
# Epoch: 89, Time: 0.00070s, Loss: 0.65215
# Epoch: 90, Time: 0.00068s, Loss: 0.57064
# Epoch: 91, Time: 0.00068s, Loss: 0.64725
# Epoch: 92, Time: 0.00068s, Loss: 0.58507
# Epoch: 93, Time: 0.00070s, Loss: 0.62494
# Epoch: 94, Time: 0.00068s, Loss: 0.58289
# Epoch: 95, Time: 0.00068s, Loss: 0.56591
# Epoch: 96, Time: 0.00068s, Loss: 0.59959
# Epoch: 97, Time: 0.00069s, Loss: 0.62588
# Epoch: 98, Time: 0.00068s, Loss: 0.58035
# Epoch: 99, Time: 0.00068s, Loss: 0.58727
# Epoch: 100, Time: 0.00071s, Loss: 0.56111
# Epoch: 101, Time: 0.00068s, Loss: 0.54035
# Epoch: 102, Time: 0.00068s, Loss: 0.56815
# Epoch: 103, Time: 0.00133s, Loss: 0.50579
# Epoch: 104, Time: 0.00070s, Loss: 0.53285
# Epoch: 105, Time: 0.00070s, Loss: 0.56204
# Epoch: 106, Time: 0.00070s, Loss: 0.51602
# Epoch: 107, Time: 0.00070s, Loss: 0.52320
# Epoch: 108, Time: 0.00069s, Loss: 0.53845
# Epoch: 109, Time: 0.00067s, Loss: 0.55428
# Epoch: 110, Time: 0.00067s, Loss: 0.52966
# Epoch: 111, Time: 0.00068s, Loss: 0.56845
# Epoch: 112, Time: 0.00068s, Loss: 0.52385
# update best: 0.79400
# Epoch: 113, Time: 0.00071s, Loss: 0.52051
# Epoch: 114, Time: 0.00074s, Loss: 0.51860
# Epoch: 115, Time: 0.00070s, Loss: 0.48878
# Epoch: 116, Time: 0.00069s, Loss: 0.50367
# Epoch: 117, Time: 0.00087s, Loss: 0.49782
# Epoch: 118, Time: 0.00081s, Loss: 0.51155
# Epoch: 119, Time: 0.00082s, Loss: 0.47739
# Epoch: 120, Time: 0.00134s, Loss: 0.50645
# Epoch: 121, Time: 0.00083s, Loss: 0.49175
# Epoch: 122, Time: 0.00081s, Loss: 0.47638
# Epoch: 123, Time: 0.00082s, Loss: 0.46064
# Epoch: 124, Time: 0.00082s, Loss: 0.44845
# Epoch: 125, Time: 0.00081s, Loss: 0.44286
# Epoch: 126, Time: 0.00070s, Loss: 0.46044
# Epoch: 127, Time: 0.00072s, Loss: 0.45707
# Epoch: 128, Time: 0.00072s, Loss: 0.50700
# Epoch: 129, Time: 0.00069s, Loss: 0.46442
# Epoch: 130, Time: 0.00069s, Loss: 0.44911
# Epoch: 131, Time: 0.00078s, Loss: 0.46168
# Epoch: 132, Time: 0.00075s, Loss: 0.47634
# Epoch: 133, Time: 0.00070s, Loss: 0.41177
# Epoch: 134, Time: 0.00069s, Loss: 0.42612
# Epoch: 135, Time: 0.00071s, Loss: 0.46436
# Epoch: 136, Time: 0.00093s, Loss: 0.42374
# Epoch: 137, Time: 0.00070s, Loss: 0.42290
# Epoch: 138, Time: 0.00068s, Loss: 0.43096
# Epoch: 139, Time: 0.00072s, Loss: 0.43386
# Epoch: 140, Time: 0.00070s, Loss: 0.47472
# Epoch: 141, Time: 0.00068s, Loss: 0.40687
# Epoch: 142, Time: 0.00070s, Loss: 0.43927
# Epoch: 143, Time: 0.00069s, Loss: 0.39323
# Epoch: 144, Time: 0.00069s, Loss: 0.42356
# Epoch: 145, Time: 0.00068s, Loss: 0.44625
# Epoch: 146, Time: 0.00067s, Loss: 0.38619
# Epoch: 147, Time: 0.00068s, Loss: 0.40754
# Epoch: 148, Time: 0.00068s, Loss: 0.38543
# Epoch: 149, Time: 0.00069s, Loss: 0.39466
# Epoch: 150, Time: 0.00068s, Loss: 0.43009
# Epoch: 151, Time: 0.00068s, Loss: 0.38695
# Epoch: 152, Time: 0.00083s, Loss: 0.41950
# Epoch: 153, Time: 0.00082s, Loss: 0.41095
# Epoch: 154, Time: 0.00085s, Loss: 0.40313
# Epoch: 155, Time: 0.00082s, Loss: 0.43876
# Epoch: 156, Time: 0.00081s, Loss: 0.40152
# Epoch: 157, Time: 0.00082s, Loss: 0.39797
# update best: 0.80000
# Epoch: 158, Time: 0.00087s, Loss: 0.35990
# Epoch: 159, Time: 0.00082s, Loss: 0.40668
# Epoch: 160, Time: 0.00081s, Loss: 0.39737
# Epoch: 161, Time: 0.00081s, Loss: 0.42709
# Epoch: 162, Time: 0.00082s, Loss: 0.40306
# Epoch: 163, Time: 0.00083s, Loss: 0.44195
# Epoch: 164, Time: 0.00081s, Loss: 0.35434
# Epoch: 165, Time: 0.00081s, Loss: 0.39269
# Epoch: 166, Time: 0.00082s, Loss: 0.32633
# Epoch: 167, Time: 0.00081s, Loss: 0.38579
# Epoch: 168, Time: 0.00084s, Loss: 0.38941
# Epoch: 169, Time: 0.00140s, Loss: 0.38425
# Epoch: 170, Time: 0.00082s, Loss: 0.39287
# Epoch: 171, Time: 0.00081s, Loss: 0.36239
# Epoch: 172, Time: 0.00082s, Loss: 0.37962
# Epoch: 173, Time: 0.00081s, Loss: 0.35394
# Epoch: 174, Time: 0.00082s, Loss: 0.34589
# Epoch: 175, Time: 0.00082s, Loss: 0.38056
# Epoch: 176, Time: 0.00081s, Loss: 0.37199
# Epoch: 177, Time: 0.00082s, Loss: 0.36108
# Epoch: 178, Time: 0.00081s, Loss: 0.37211
# Epoch: 179, Time: 0.00068s, Loss: 0.35234
# Epoch: 180, Time: 0.00068s, Loss: 0.33577
# Epoch: 181, Time: 0.00067s, Loss: 0.37541
# Epoch: 182, Time: 0.00067s, Loss: 0.30629
# Epoch: 183, Time: 0.00068s, Loss: 0.36643
# Epoch: 184, Time: 0.00067s, Loss: 0.34131
# Epoch: 185, Time: 0.00131s, Loss: 0.35421
# Epoch: 186, Time: 0.00068s, Loss: 0.33999
# Epoch: 187, Time: 0.00068s, Loss: 0.36365
# Epoch: 188, Time: 0.00067s, Loss: 0.36926
# Epoch: 189, Time: 0.00115s, Loss: 0.31029
# Epoch: 190, Time: 0.00091s, Loss: 0.32959
# Epoch: 191, Time: 0.00095s, Loss: 0.35637
# Epoch: 192, Time: 0.00093s, Loss: 0.30936
# Epoch: 193, Time: 0.00094s, Loss: 0.32842
# Epoch: 194, Time: 0.00098s, Loss: 0.31046
# Epoch: 195, Time: 0.00107s, Loss: 0.34217
# Epoch: 196, Time: 0.00102s, Loss: 0.35384
# Epoch: 197, Time: 0.00163s, Loss: 0.31096
# Epoch: 198, Time: 0.00154s, Loss: 0.31790
# Epoch: 199, Time: 0.00180s, Loss: 0.29574
# Epoch: 200, Time: 0.00178s, Loss: 0.32036
# Epoch: 201, Time: 0.00177s, Loss: 0.33968
# Epoch: 202, Time: 0.00163s, Loss: 0.35758
# Epoch: 203, Time: 0.00157s, Loss: 0.33569
# Epoch: 204, Time: 0.00153s, Loss: 0.30722
# Epoch: 205, Time: 0.00219s, Loss: 0.32825
# Epoch: 206, Time: 0.00149s, Loss: 0.31308
# Epoch: 207, Time: 0.00150s, Loss: 0.30405
# Epoch: 208, Time: 0.00134s, Loss: 0.31380
# Epoch: 209, Time: 0.00123s, Loss: 0.29651
# Epoch: 210, Time: 0.00122s, Loss: 0.35048
# Epoch: 211, Time: 0.00131s, Loss: 0.28948
# Epoch: 212, Time: 0.00096s, Loss: 0.32826
# Epoch: 213, Time: 0.00092s, Loss: 0.33542
# Epoch: 214, Time: 0.00089s, Loss: 0.31759
# Epoch: 215, Time: 0.00147s, Loss: 0.33522
# Epoch: 216, Time: 0.00086s, Loss: 0.33352
# Epoch: 217, Time: 0.00081s, Loss: 0.31497
# Epoch: 218, Time: 0.00079s, Loss: 0.29437
# Epoch: 219, Time: 0.00078s, Loss: 0.33080
# Epoch: 220, Time: 0.00069s, Loss: 0.29301
# Epoch: 221, Time: 0.00077s, Loss: 0.33217
# Epoch: 222, Time: 0.00081s, Loss: 0.29028
# Epoch: 223, Time: 0.00079s, Loss: 0.32554
# Epoch: 224, Time: 0.00078s, Loss: 0.32568
# Epoch: 225, Time: 0.00079s, Loss: 0.29902
# Epoch: 226, Time: 0.00077s, Loss: 0.30278
# Epoch: 227, Time: 0.00078s, Loss: 0.31784
# Epoch: 228, Time: 0.00078s, Loss: 0.31956
# Epoch: 229, Time: 0.00069s, Loss: 0.33015
# Epoch: 230, Time: 0.00067s, Loss: 0.32676
# Epoch: 231, Time: 0.00071s, Loss: 0.30811
# Epoch: 232, Time: 0.00068s, Loss: 0.30206
# Epoch: 233, Time: 0.00068s, Loss: 0.28622
# Epoch: 234, Time: 0.00068s, Loss: 0.30973
# Epoch: 235, Time: 0.00072s, Loss: 0.29778
# Epoch: 236, Time: 0.00068s, Loss: 0.32751
# Epoch: 237, Time: 0.00070s, Loss: 0.29516
# Epoch: 238, Time: 0.00069s, Loss: 0.32534
# Epoch: 239, Time: 0.00069s, Loss: 0.30352
# Epoch: 240, Time: 0.00067s, Loss: 0.33049
# Epoch: 241, Time: 0.00067s, Loss: 0.31402
# Epoch: 242, Time: 0.00068s, Loss: 0.28515
# Epoch: 243, Time: 0.00067s, Loss: 0.29302
# Epoch: 244, Time: 0.00068s, Loss: 0.30092
# Epoch: 245, Time: 0.00067s, Loss: 0.30158
# Epoch: 246, Time: 0.00067s, Loss: 0.30584
# Epoch: 247, Time: 0.00067s, Loss: 0.28340
# Epoch: 248, Time: 0.00066s, Loss: 0.28946
# Epoch: 249, Time: 0.00070s, Loss: 0.30420
# Epoch: 250, Time: 0.00068s, Loss: 0.31300
# Epoch: 251, Time: 0.00067s, Loss: 0.27307
# Epoch: 252, Time: 0.00067s, Loss: 0.29203
# Epoch: 253, Time: 0.00067s, Loss: 0.28938
# Epoch: 254, Time: 0.00067s, Loss: 0.26516
# Epoch: 255, Time: 0.00067s, Loss: 0.29329
# Epoch: 256, Time: 0.00068s, Loss: 0.29358
# Epoch: 257, Time: 0.00067s, Loss: 0.27872
# Epoch: 258, Time: 0.00066s, Loss: 0.29461
# Epoch: 259, Time: 0.00066s, Loss: 0.26567
# Epoch: 260, Time: 0.00066s, Loss: 0.29477
# Epoch: 261, Time: 0.00066s, Loss: 0.30584
# Epoch: 262, Time: 0.00065s, Loss: 0.26011
# Epoch: 263, Time: 0.00066s, Loss: 0.30692
# Epoch: 264, Time: 0.00066s, Loss: 0.27051
# Epoch: 265, Time: 0.00068s, Loss: 0.25835
# Epoch: 266, Time: 0.00067s, Loss: 0.31619
# Epoch: 267, Time: 0.00070s, Loss: 0.30174
# Epoch: 268, Time: 0.00067s, Loss: 0.26034
# Epoch: 269, Time: 0.00066s, Loss: 0.27808
# Epoch: 270, Time: 0.00066s, Loss: 0.29332
# Epoch: 271, Time: 0.00066s, Loss: 0.26692
# Epoch: 272, Time: 0.00066s, Loss: 0.28851
# Epoch: 273, Time: 0.00065s, Loss: 0.26747
# Epoch: 274, Time: 0.00072s, Loss: 0.30790
# Epoch: 275, Time: 0.00071s, Loss: 0.28764
# Epoch: 276, Time: 0.00067s, Loss: 0.30085
# Epoch: 277, Time: 0.00067s, Loss: 0.28411
# Epoch: 278, Time: 0.00066s, Loss: 0.26994
# Epoch: 279, Time: 0.00067s, Loss: 0.26031
# Epoch: 280, Time: 0.00066s, Loss: 0.27309
# Epoch: 281, Time: 0.00067s, Loss: 0.25698
# Epoch: 282, Time: 0.00067s, Loss: 0.28126
# Epoch: 283, Time: 0.00067s, Loss: 0.26360
# Epoch: 284, Time: 0.00066s, Loss: 0.28284
# Epoch: 285, Time: 0.00070s, Loss: 0.24613
# Epoch: 286, Time: 0.00066s, Loss: 0.26301
# Epoch: 287, Time: 0.00067s, Loss: 0.28754
# Epoch: 288, Time: 0.00065s, Loss: 0.28218
# Epoch: 289, Time: 0.00067s, Loss: 0.26176
# Epoch: 290, Time: 0.00067s, Loss: 0.26771
# Epoch: 291, Time: 0.00071s, Loss: 0.28082
# Epoch: 292, Time: 0.00068s, Loss: 0.27299
# Epoch: 293, Time: 0.00067s, Loss: 0.28459
# Epoch: 294, Time: 0.00066s, Loss: 0.24006
# Epoch: 295, Time: 0.00066s, Loss: 0.25937
# Epoch: 296, Time: 0.00066s, Loss: 0.27928
# Epoch: 297, Time: 0.00066s, Loss: 0.27713
# Epoch: 298, Time: 0.00067s, Loss: 0.24161
# Epoch: 299, Time: 0.00067s, Loss: 0.27042
#
# train finished!
# best val: 0.80000
# test...
# final result: epoch: 157
# {'accuracy': 0.8230000138282776, 'f1_score': 0.8135442845966843, 'f1_score -> average@micro': 0.823}
